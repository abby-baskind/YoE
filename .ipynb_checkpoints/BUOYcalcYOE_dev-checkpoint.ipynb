# %%
from matplotlib import pyplot as plt
from matplotlib.dates import DateFormatter
import numpy as np
import xarray as xr
import pandas as pd
import scipy
from datetime import datetime, timedelta
import time
import seaborn
import matplotlib.dates as mdates
import bottleneck as bn
import PyCO2SYS as pyco2
import gsw
import math
import netCDF4 as nc
import requests

# import chemO_funcs #import o2sat
from importlib import reload
import warnings
warnings.filterwarnings('ignore')
import cartopy.crs as ccrs
import cartopy.mpl.ticker as cticker
# %run ./chemO_funcs.py

# %% [markdown]
# # Combine GFDL data from past present and future

# %%
ddpast = xr.open_mfdataset('/Users/akbaskind/Desktop/YoE/GFDLESM4historical_1850_2000_means.nc')
ddpresent = xr.open_mfdataset('/Users/akbaskind/Desktop/YoE/GFDLESM4historical_1995_2015.nc')
ddfuture = xr.open_mfdataset('/Users/akbaskind/Desktop/YoE/GFDLESM4future_2015_2035.nc')
ddfuture2 = xr.open_mfdataset('/Users/akbaskind/Desktop/YoE/GFDLESM4_2035_2060.nc')
ddfuture3 = xr.open_mfdataset('/Users/akbaskind/Desktop/YoE/GFDLCM4_future_2060_2085.nc')

# %%
ddfuture3.time
# Out:
# <xarray.DataArray 'time' (time: 300)>
# array([cftime.DatetimeNoLeap(2060, 1, 16, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2060, 2, 15, 0, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2060, 3, 16, 12, 0, 0, 0, has_year_zero=True),
#        ...,
#        cftime.DatetimeNoLeap(2084, 10, 16, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2084, 11, 16, 0, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2084, 12, 16, 12, 0, 0, 0, has_year_zero=True)],
#       dtype=object)
# Coordinates:
#   * time            (time) object 2060-01-16 12:00:00 ... 2084-12-16 12:00:00
#     time_bounds     (time) object dask.array<chunksize=(300,), meta=np.ndarray>
#     member_id       object ...
#     dcpp_init_year  float64 ...
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     calendar_type:  noleap
#     description:    Temporal mean
#     long_name:      time
#     standard_name:  time

# %% [markdown]
# ## present data
# ### Detrend

# %%
ds = ddpresent

# %%
ds['fCO2_detrended'] = (ds['fCO2'] -  1.89 * (ds['fCO2'].time.dt.year - 2000)) * xr.ones_like(ds['talkos'])
ds['ph_detrended'] = (ds['phos'] + 0.0018 * (ds['phos'].time.dt.year - 2000)) * xr.ones_like(ds['talkos'])
ds['OmegaAr_detrended'] = (ds['OmegaAr'] + 0.0078 * (ds['OmegaAr'].time.dt.year - 2000)) * xr.ones_like(ds['talkos'])
ds
# Out:
# <xarray.Dataset>
# Dimensions:            (y: 180, x: 360, time: 240)
# Coordinates:
#   * y                  (y) float64 -89.5 -88.5 -87.5 -86.5 ... 87.5 88.5 89.5
#     lat_bounds         (y, x) float64 dask.array<chunksize=(180, 360), meta=np.ndarray>
#   * x                  (x) float64 0.5 1.5 2.5 3.5 ... 356.5 357.5 358.5 359.5
#     lon_bounds         (x, y) float64 dask.array<chunksize=(360, 180), meta=np.ndarray>
#   * time               (time) object 1995-01-16 12:00:00 ... 2014-12-16 12:00:00
#     time_bounds        (time) object dask.array<chunksize=(240,), meta=np.ndarray>
#     lon                (x, y) float64 dask.array<chunksize=(360, 180), meta=np.ndarray>
#     lat                (x, y) float64 dask.array<chunksize=(360, 180), meta=np.ndarray>
#     lon_verticies      (x, y) float64 dask.array<chunksize=(360, 180), meta=np.ndarray>
#     lat_verticies      (x, y) float64 dask.array<chunksize=(360, 180), meta=np.ndarray>
#     member_id          object ...
# ...

# %% [markdown]
# ### take an annual mean

# %%
ddpresent_ann = ds.groupby('time.year').mean(dim="time")
ddpresent_ann
# Out:
# <xarray.Dataset>
# Dimensions:            (y: 180, x: 360, year: 20)
# Coordinates:
#   * y                  (y) float64 -89.5 -88.5 -87.5 -86.5 ... 87.5 88.5 89.5
#     lat_bounds         (y, x) float64 dask.array<chunksize=(180, 360), meta=np.ndarray>
#   * x                  (x) float64 0.5 1.5 2.5 3.5 ... 356.5 357.5 358.5 359.5
#     lon_bounds         (x, y) float64 dask.array<chunksize=(360, 180), meta=np.ndarray>
#     lon                (x, y) float64 dask.array<chunksize=(360, 180), meta=np.ndarray>
#     lat                (x, y) float64 dask.array<chunksize=(360, 180), meta=np.ndarray>
#     lon_verticies      (x, y) float64 dask.array<chunksize=(360, 180), meta=np.ndarray>
#     lat_verticies      (x, y) float64 dask.array<chunksize=(360, 180), meta=np.ndarray>
#     member_id          object ...
#     dcpp_init_year     float64 ...
#   * year               (year) int64 1995 1996 1997 1998 ... 2011 2012 2013 2014
# Data variables:
# ...

# %% [markdown]
# ## future data
# ### detrend

# %%
ds = ddfuture
ds2 = ddfuture2
ds3 = ddfuture3

# %%
ds['fCO2_detrended'] = (ds['fCO2'] -  1.89 * (ds['fCO2'].time.dt.year - 2000)) * xr.ones_like(ds['talkos'])
ds['ph_detrended'] = (ds['phos'] + 0.0018 * (ds['phos'].time.dt.year - 2000)) * xr.ones_like(ds['talkos'])
ds['OmegaAr_detrended'] = (ds['OmegaAr'] + 0.0078 * (ds['OmegaAr'].time.dt.year - 2000)) * xr.ones_like(ds['talkos'])

ds2['fCO2_detrended'] = (ds2['fCO2'] -  1.89 * (ds2['fCO2'].time.dt.year - 2000)) * xr.ones_like(ds2['talkos'])
ds2['ph_detrended'] = (ds2['phos'] + 0.0018 * (ds2['phos'].time.dt.year - 2000)) * xr.ones_like(ds2['talkos'])
ds2['OmegaAr_detrended'] = (ds2['OmegaAr'] + 0.0078 * (ds2['OmegaAr'].time.dt.year - 2000)) * xr.ones_like(ds2['talkos'])

# %%
ddfuture_ann = ds.groupby('time.year').mean(dim="time")
ddfuture_ann2 = ds2.groupby('time.year').mean(dim="time")
ddfuture_ann3 = ds3.groupby('time.year').mean(dim="time")
ddfuture_ann3.year
# Out:
# <xarray.DataArray 'year' (year: 25)>
# array([2060, 2061, 2062, 2063, 2064, 2065, 2066, 2067, 2068, 2069, 2070, 2071,
#        2072, 2073, 2074, 2075, 2076, 2077, 2078, 2079, 2080, 2081, 2082, 2083,
#        2084])
# Coordinates:
#     member_id       object ...
#     dcpp_init_year  float64 ...
#   * year            (year) int64 2060 2061 2062 2063 ... 2081 2082 2083 2084

# %% [markdown]
# ## Create dataset with time dimensions of
# ```python
# array([1850, 1860, 1870, 1880, 1890, 1900, 1910, 1920, 1930, 1940, 1950,
#        1960, 1970, 1980, 1990, 1995, 1996, 1997, 1998, 1999, 2000, 2001,
#        2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#        2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023,
#        2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034])
# ```
# Where years prior to 1995 indicate decadal means

# %% [markdown]
# ## Fill total GFDL dataframe
# coords are lat, lon, and time

# %%
ddfuture_ann
# Out:
# <xarray.Dataset>
# Dimensions:         (year: 20, y: 180, x: 360)
# Coordinates:
#   * y               (y) float64 -89.5 -88.5 -87.5 -86.5 ... 86.5 87.5 88.5 89.5
#     lat_bounds      (y, x) float64 dask.array<chunksize=(180, 360), meta=np.ndarray>
#   * x               (x) float64 0.5 1.5 2.5 3.5 4.5 ... 356.5 357.5 358.5 359.5
#     lon_bounds      (x, y) float64 dask.array<chunksize=(360, 180), meta=np.ndarray>
#     lon             (x, y) float64 dask.array<chunksize=(360, 180), meta=np.ndarray>
#     lat             (x, y) float64 dask.array<chunksize=(360, 180), meta=np.ndarray>
#     lon_verticies   (x, y) float64 dask.array<chunksize=(360, 180), meta=np.ndarray>
#     lat_verticies   (x, y) float64 dask.array<chunksize=(360, 180), meta=np.ndarray>
#     member_id       object ...
#     dcpp_init_year  float64 ...
#   * year            (year) int64 2015 2016 2017 2018 ... 2031 2032 2033 2034
# Data variables:
# ...

# %%
dd = xr.Dataset()
T = np.concatenate((np.arange(1850,2000,10), np.arange(1995,2085,1)))
dd = dd.assign_coords({'t': T})
dat = np.zeros((len(dd.t)))
dat[:] = np.nan
dd['fCO2'] = xr.Variable(dims = ['t'], data = dat)
dd['OmegaAr'] = xr.Variable(dims = ['t'], data = dat)
dd['ph'] = xr.Variable(dims = ['t'], data = dat)
var = 'fCO2'
for i in T:
    var = 'fCO2'
    if i < 1995:
        dd[var] = xr.where(dd['t'] == i, ddpast[var].sel(t = i), dd[var])
    elif i < 2015:
        dd[var] = xr.where(dd['t'] == i, ddpresent_ann[var].sel(year = i), dd[var]) 
    elif i < 2035:
        dd[var] = xr.where(dd['t'] == i, ddfuture_ann[var].sel(year = i), dd[var])
    elif i < 2060:
        dd[var] = xr.where(dd['t'] == i, ddfuture_ann2[var].sel(year = i), dd[var])
    elif i < 2085:
        dd[var] = xr.where(dd['t'] == i, ddfuture_ann3[var].sel(year = i), dd[var])
    var = 'OmegaAr'
    if i < 1995:
        dd[var] = xr.where(dd['t'] == i, ddpast[var].sel(t = i), dd[var])
    elif i < 2015:
        dd[var] = xr.where(dd['t'] == i, ddpresent_ann[var].sel(year = i), dd[var]) 
    elif i < 2035:
        dd[var] = xr.where(dd['t'] == i, ddfuture_ann[var].sel(year = i), dd[var])
    elif i < 2060:
        dd[var] = xr.where(dd['t'] == i, ddfuture_ann2[var].sel(year = i), dd[var])
    elif i < 2085:
        dd[var] = xr.where(dd['t'] == i, ddfuture_ann3[var].sel(year = i), dd[var])
    var = 'ph'
    if i < 1995:
        dd[var] = xr.where(dd['t'] == i, ddpast['ph'].sel(t = i), dd[var])
    elif i < 2015:
        dd[var] = xr.where(dd['t'] == i, ddpresent_ann['phos'].sel(year = i), dd[var]) 
    elif i < 2035:
        dd[var] = xr.where(dd['t'] == i, ddfuture_ann['phos'].sel(year = i), dd[var])
    elif i < 2060:
        dd[var] = xr.where(dd['t'] == i, ddfuture_ann2['phos'].sel(year = i), dd[var])
    elif i < 2085:
        dd[var] = xr.where(dd['t'] == i, ddfuture_ann3['phos'].sel(year = i), dd[var])

# %%
dd
# Out:
# <xarray.Dataset>
# Dimensions:         (t: 105, y: 180, x: 360)
# Coordinates:
#   * t               (t) int64 1850 1860 1870 1880 1890 ... 2081 2082 2083 2084
#   * y               (y) float64 -89.5 -88.5 -87.5 -86.5 ... 86.5 87.5 88.5 89.5
#   * x               (x) float64 0.5 1.5 2.5 3.5 4.5 ... 356.5 357.5 358.5 359.5
#     lat_bounds      (y, x) float64 dask.array<chunksize=(180, 360), meta=np.ndarray>
#     lon_bounds      (x, y) float64 dask.array<chunksize=(360, 180), meta=np.ndarray>
#     lon             (x, y) float64 dask.array<chunksize=(360, 180), meta=np.ndarray>
#     lat             (x, y) float64 dask.array<chunksize=(360, 180), meta=np.ndarray>
#     lon_verticies   (x, y) float64 dask.array<chunksize=(360, 180), meta=np.ndarray>
#     lat_verticies   (x, y) float64 dask.array<chunksize=(360, 180), meta=np.ndarray>
#     member_id       object ...
#     dcpp_init_year  float64 ...
#     year            int64 1995
# Data variables:
# ...

# %% [markdown]
# ## Save GFDL data

# %%
dd.to_netcdf('/Users/akbaskind/Desktop/YoE/GFDLESM4_1850_2060_decadalandannual.nc')

# %% [markdown]
# ## Open all GFDL data

# %%
dd = xr.open_mfdataset('/Users/akbaskind/Desktop/YoE/GFDLESM4_1850_2060_decadalandannual.nc')

# %% [markdown]
# ## Open Noise data
# `NOISE_091423.csv` has noise from correlations with no outliers removed and no division by depth. All the noise in this is calculated from GFDL noise using the simple correlations.

# %%
NOISE = pd.read_csv('/Users/akbaskind/Desktop/YoE/NOISE_091423.csv')

# %%
NOISE
# Out:
#        Unnamed: 0   Lat    Lon  Final Noise fCO2  Final Noise pH  \
# 0               0 -77.5  162.5         50.582744        0.095759
# 1               1 -77.5  163.5         58.503272        0.122839
# 2               2 -77.5  164.5         57.057182        0.116445
# 3               3 -77.5  165.5         53.610083        0.106269
# 4               4 -77.5  166.5         54.581585        0.105474
# ...           ...   ...    ...               ...             ...
# 44559       44559  89.5  355.5         24.470364        0.033428
# 44560       44560  89.5  356.5         24.466296        0.033420
# 44561       44561  89.5  357.5         24.459343        0.033405
# 44562       44562  89.5  358.5         24.453812        0.033393
# 44563       44563  89.5  359.5         24.449731        0.033385
#
#        Final Noise Omega
# 0               0.343437
# 1               0.470882
# 2               0.457394
# 3               0.447320
# 4               0.445448
# ...                  ...
# ...

# %%
place = NOISE.index[(NOISE['Lat']==89.5) & (NOISE['Lon'] == 355.5)].to_list()[0]
NOISE['Final Noise pH'][place]
# Out:
# 0.033427948434

# %% [markdown]
# # Loop through all coordinate points, calculate 5th order polynomial, solve for pHYOE, append to dictionary

# %%
temp = {'Lat':[], 'Lon': [], '1850 pH': [], 'YOE Projected pH': [],
       'YOE Actual pH from polynomial': [], 'YOE': []}

tt = np.arange(1850,2060,1)
for i in dd.x:
    for j in dd.y:
        
        ds = dd.sel(x = i, y = j, method = 'nearest')
        if not math.isnan(ds.ph.values.tolist()[0]):
            J = round(j.values.tolist(), 2)
            I = round(i.values.tolist(), 2)
            temp['Lon'].append(I)
            temp['Lat'].append(J)
            
            # Create 5th order polynomial
            px = np.poly1d(np.polyfit(ds.t, ds.ph, 5))
            # Solutions to the 5th order polynomial
            sols = px[0] + px[1] * tt + px[2] * tt**2 + px[3] * tt**3 + px[4] * tt**4 + px[5] * tt**5 
            
            # Find the noise corresponding to the coords in NOISE dataset
            place = NOISE.index[(NOISE['Lat']==J) & (NOISE['Lon'] == I)].to_list()[0]
            noise_ph = NOISE['Final Noise pH'][place]
            # noise = 0.03
            
            projph = ds.ph.isel(t = 0) - 2*noise_ph
            temp['1850 pH'].append(ds.ph.isel(t = 0).values.tolist())
            PROJPH = projph.values.tolist()
            temp['YOE Projected pH'].append(PROJPH)
            if PROJPH < sols.min() or PROJPH > sols.max():
                warnings.warn('YOE cannot be found at (' + str(i.values.tolist()) + ', ' + str(j.values.tolist()) + ')')
                temp['YOE Actual pH from polynomial'].append(np.nan)
                temp['YOE'].append(np.nan)
            else: 
                YOEindex = list(map(lambda m: m < PROJPH, sols.tolist())).index(True)
                YOE = tt[YOEindex]
                temp['YOE Actual pH from polynomial'].append(sols[YOEindex])
                temp['YOE'].append(tt[YOEindex])

# %%
ph = pd.DataFrame(temp)
ph.dropna()
ph = ph.reset_index(drop = True)
ph.to_csv('/Users/akbaskind/Desktop/YoE/phYOE_091423.csv')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:         (t: 55)
# Coordinates:
#   * t               (t) int64 1850 1860 1870 1880 1890 ... 2031 2032 2033 2034
#     y               float64 89.5
#     x               float64 359.5
#     lat_bounds      float64 dask.array<chunksize=(), meta=np.ndarray>
#     lon_bounds      float64 dask.array<chunksize=(), meta=np.ndarray>
#     lon             float64 dask.array<chunksize=(), meta=np.ndarray>
#     lat             float64 dask.array<chunksize=(), meta=np.ndarray>
#     lon_verticies   float64 dask.array<chunksize=(), meta=np.ndarray>
#     lat_verticies   float64 dask.array<chunksize=(), meta=np.ndarray>
#     member_id       object ...
#     dcpp_init_year  float64 ...
#     year            int64 ...
# Data variables:
#     fCO2            (t) float64 dask.array<chunksize=(55,), meta=np.ndarray>
#     OmegaAr         (t) float64 dask.array<chunksize=(55,), meta=np.ndarray>
# ...

# %% [markdown]
# # fCO2 YOE

# %%
temp = {'Lat':[], 'Lon': [], '1850 fCO2': [], 'YOE Projected fCO2': [],
       'YOE Actual fCO2 from polynomial': [], 'YOE': []}

tt = np.arange(1850,2100,1)
for i in dd.x:
    for j in dd.y:
        
        ds = dd.sel(x = i, y = j, method = 'nearest')
        if not math.isnan(ds.fCO2.values.tolist()[0]):
            J = round(j.values.tolist(), 2)
            I = round(i.values.tolist(), 2)
            temp['Lon'].append(I)
            temp['Lat'].append(J)
            
            # Create 5th order polynomial
            px = np.poly1d(np.polyfit(ds.t, ds.fCO2, 5))
            # Solutions to the 5th order polynomial
            sols = px[0] + px[1] * tt + px[2] * tt**2 + px[3] * tt**3 + px[4] * tt**4 + px[5] * tt**5 
            
            # Find the noise corresponding to the coords in NOISE dataset
            place = NOISE.index[(NOISE['Lat']==J) & (NOISE['Lon'] == I)].to_list()[0]
            noise_fco2 = NOISE['Final Noise fCO2'][place]
            # noise = 0.03
            
            projfco2 = ds.fCO2.isel(t = 0) + 2*noise_fco2
            temp['1850 fCO2'].append(ds.fCO2.isel(t = 0).values.tolist())
            PROJFCO2 = projfco2.values.tolist()
            temp['YOE Projected fCO2'].append(PROJFCO2)
            if PROJFCO2 < sols.min() or PROJFCO2 > sols.max():
                # warnings.warn('YOE cannot be found at (' + str(i.values.tolist()) + ', ' + str(j.values.tolist()) + ')')
                temp['YOE Actual fCO2 from polynomial'].append(np.nan)
                temp['YOE'].append(np.nan)
            else: 
                YOEindex = list(map(lambda m: m > PROJFCO2, sols.tolist())).index(True)
                YOE = tt[YOEindex]
                temp['YOE Actual fCO2 from polynomial'].append(sols[YOEindex])
                temp['YOE'].append(tt[YOEindex])

# %%
fco2 = pd.DataFrame(temp)
fco2.dropna()
fco2 = fco2.reset_index(drop = True)
fco2.to_csv('/Users/akbaskind/Desktop/YoE/fco2YOE_091423.csv')

# %% [markdown]
# # Ω YOE

# %%
ds = dd.sel(x = i, y = j, method = 'nearest')
ds
# Out:
# <xarray.Dataset>
# Dimensions:         (t: 55)
# Coordinates:
#   * t               (t) int64 1850 1860 1870 1880 1890 ... 2031 2032 2033 2034
#     y               float64 -65.5
#     x               float64 0.5
#     lat_bounds      float64 dask.array<chunksize=(), meta=np.ndarray>
#     lon_bounds      float64 dask.array<chunksize=(), meta=np.ndarray>
#     lon             float64 dask.array<chunksize=(), meta=np.ndarray>
#     lat             float64 dask.array<chunksize=(), meta=np.ndarray>
#     lon_verticies   float64 dask.array<chunksize=(), meta=np.ndarray>
#     lat_verticies   float64 dask.array<chunksize=(), meta=np.ndarray>
#     member_id       object ...
#     dcpp_init_year  float64 ...
#     year            int64 ...
# Data variables:
#     fCO2            (t) float64 dask.array<chunksize=(55,), meta=np.ndarray>
#     OmegaAr         (t) float64 dask.array<chunksize=(55,), meta=np.ndarray>
# ...

# %%
temp = {'Lat':[], 'Lon': [], '1850 Omega': [], 'YOE Projected Omega': [],
       'YOE Actual Omega from polynomial': [], 'YOE': []}

tt = np.arange(1850,2100,1)
for i in dd.x:
    for j in dd.y:
        
        ds = dd.sel(x = i, y = j, method = 'nearest')
        if not math.isnan(ds.OmegaAr.values.tolist()[0]):
            J = round(j.values.tolist(), 2)
            I = round(i.values.tolist(), 2)
            temp['Lon'].append(I)
            temp['Lat'].append(J)
            
            # Create 5th order polynomial
            px = np.poly1d(np.polyfit(ds.t, ds.OmegaAr, 5))
            # Solutions to the 5th order polynomial
            sols = px[0] + px[1] * tt + px[2] * tt**2 + px[3] * tt**3 + px[4] * tt**4 + px[5] * tt**5 
            
            # Find the noise corresponding to the coords in NOISE dataset
            place = NOISE.index[(NOISE['Lat']==J) & (NOISE['Lon'] == I)].to_list()[0]
            noise_omega = NOISE['Final Noise Omega'][place]
            # noise = 0.03
            
            projomega = ds.OmegaAr.isel(t = 0) - 2*noise_omega
            temp['1850 Omega'].append(ds.OmegaAr.isel(t = 0).values.tolist())
            PROJOMEGA = projomega.values.tolist()
            temp['YOE Projected Omega'].append(PROJOMEGA)
            if PROJOMEGA < sols.min() or PROJOMEGA > sols.max():
                # warnings.warn('YOE cannot be found at (' + str(i.values.tolist()) + ', ' + str(j.values.tolist()) + ')')
                temp['YOE Actual Omega from polynomial'].append(np.nan)
                temp['YOE'].append(np.nan)
            else: 
                YOEindex = list(map(lambda m: m < PROJOMEGA, sols.tolist())).index(True)
                # if math.isnan(YOEindex):
                #     YOEindex = list(map(lambda m: m > PROJOMEGA, sols.tolist())).index(True)
                YOE = tt[YOEindex]
                temp['YOE Actual Omega from polynomial'].append(sols[YOEindex])
                temp['YOE'].append(tt[YOEindex])

# %%
pink = '#ff6289'
purple = '#C79FEF'
blue = '#82e9ff'
green = '#C1F80A'

# Greens
caribbean_green = '#00cc99'
emerald = '#319177'
crayola_green = '#1cac78'
jade = '#00a86b'
kelly = '#4cbb17'
yellowgreen = '#9acd32'

# Blues
french_sky_blue = '#77b5fe'
opal = '#a8c3bc'
baby_blue = '#89cff0'
tiffany_blue = '#0abab5'
cornflower = '#6495ed'

# Pinks
hollywood_cerise = '#f400a1'
baker_miller = '#ff91af'
wild_strawberry = '#ff43a4'

# Purples
iris = '#5a4fcf'
orchid = '#9932cc'
amethyst = '#9966cc'
wisteria = '#c9a0dc'

# Oranges
neon_carrot = '#ffa343'
gamboge = '#e49b0f'
carrot = '#ed9121'

# Yellows
sunglow = '#ffcc33'
bitter_lemon = '#cae00d'
pantone_yellow = '#fedf00'

# Reds
candy_apple = '#e2062c'
carmine = '#eb4c42'
coquelicot = '#ff3800'

# %%
fig, axarr = plt.subplots(ncols = 3, figsize = [20,6])
axarr = axarr.flatten()
plt.rcParams.update({'font.size': 14})
plt.rc('xtick', labelsize=12)
plt.rc('ytick', labelsize=12)

# Select a location
ds = dd.sel(x = 25.5, y = -70.5, method = 'nearest')
tt = np.arange(1850,2100,1)

# PH
# Model
px = np.poly1d(np.polyfit(ds.t, ds.ph, 5))
sols_ph = px[0] + px[1] * tt + px[2] * tt**2 + px[3] * tt**3 + px[4] * tt**4 + px[5] * tt**5
ax = axarr[0]
ax.plot(tt,sols_ph, c = iris, label = '5th order polynomial model')
ax.scatter(ds.t, ds.ph, c = carrot,label = 'GFDL-ESM4')
# Noise
y = NOISE['Final Noise pH'].where(NOISE['Lat'] == -70.5).where(NOISE['Lon'] == 25.5).dropna().values.tolist()[0]
ax.fill_between(tt, sols_ph - y, sols_ph + y, color = iris, alpha = 0.2)
ax.fill_between(tt, sols_ph[0] - 2*y - y, sols_ph[0] - 2*y + y, color = jade, alpha = 0.2)
# YOE
yoe = ph['YOE'].where(ph['Lat'] == -70.5).where(ph['Lon'] == 25.5).dropna().tolist()[0]
ax.errorbar(yoe, sols_ph[0] - 2*y, yerr = y, marker = 'o', capsize = 3, color = jade)
ax.set_ylabel('pH')
ax.set_xlabel('Year')
ax.set_title('pH')

# FCO2
# Model
px = np.poly1d(np.polyfit(ds.t, ds.fCO2, 5))
sols_fco2 = px[0] + px[1] * tt + px[2] * tt**2 + px[3] * tt**3 + px[4] * tt**4 + px[5] * tt**5
ax = axarr[1]
ax.plot(tt,sols_fco2, c = iris, label = '5th order polynomial model')
ax.scatter(ds.t, ds.fCO2, c = carrot, label = 'GFDL-ESM4')
# Noise
y = NOISE['Final Noise fCO2'].where(NOISE['Lat'] == -70.5).where(NOISE['Lon'] == 25.5).dropna().values.tolist()[0]
ax.fill_between(tt, sols_fco2 - y, sols_fco2 + y, color = iris, alpha = 0.2)
ax.fill_between(tt, sols_fco2[0] + 2*y - y, sols_fco2[0] + 2*y + y, color = jade, alpha = 0.2)
# YOE
yoe = fco2['YOE'].where(fco2['Lat'] == -70.5).where(fco2['Lon'] == 25.5).dropna().tolist()[0]
ax.errorbar(yoe, sols_fco2[0] + 2*y, yerr = y, marker = 'o', capsize = 3, color = jade)
ax.set_ylabel('fCO$_2$')
ax.set_xlabel('Year')
ax.set_title('fCO$_2$')

# OMEGA
# Model
px = np.poly1d(np.polyfit(ds.t, ds.OmegaAr, 5))
sols = px[0] + px[1] * tt + px[2] * tt**2 + px[3] * tt**3 + px[4] * tt**4 + px[5] * tt**5  #+ px[6] * tt**6
ax = axarr[2]
ax.plot(tt,sols, c = iris, label = '5th order polynomial model')
ax.scatter(ds.t, ds.OmegaAr, c = carrot, label = 'GFDL-ESM4')
# Noise
y = NOISE['Final Noise Omega'].where(NOISE['Lat'] == -70.5).where(NOISE['Lon'] == 25.5).dropna().values.tolist()[0]
ax.fill_between(tt, sols - y, sols + y, color = iris, alpha = 0.2)
# YOE
yoe = omega['YOE'].where(omega['Lat'] == -70.5).where(omega['Lon'] == 25.5).dropna().tolist()[0]
ax.errorbar(yoe, sols[0] - 2*y, yerr = y, marker = 'o', capsize = 3, color = jade, label = 'Year of Emergence')
ax.set_ylabel('Ω$_{arag}$')
ax.fill_between(tt, sols[0] - 2*y - y, sols[0] - 2*y + y, color = jade, alpha = 0.2)
ax.set_xlabel('Year')
ax.set_title('Ω$_{arag}$')
ax.legend(bbox_to_anchor=(2, 0.5))

fig.suptitle('70.5°S, 25.5°')
fig.savefig('/Users/akbaskind/Documents/Python Scripts/YoE/70_5_25_5.png', bbox_inches='tight')

# %%
omega['YOE'].where(omega['Lat'] == -70.5).where(omega['Lon'] == 25.5).dropna().tolist()[0]
# Out:
# 2062.0

# %%
omega
# Out:
#         Lat    Lon  1850 Omega  YOE Projected Omega  \
# 0     -70.5    0.5    1.876329             1.336503
# 1     -69.5    0.5    1.804165             1.402623
# 2     -68.5    0.5    1.716700             1.440472
# 3     -67.5    0.5    1.727352             1.441483
# 4     -66.5    0.5    1.740176             1.462859
# ...     ...    ...         ...                  ...
# 44559  85.5  359.5    1.928166             1.665776
# 44560  86.5  359.5    1.951481             1.700606
# 44561  87.5  359.5    1.959827             1.724169
# 44562  88.5  359.5    1.952229             1.724848
# 44563  89.5  359.5    1.955232             1.728795
#
#        YOE Actual Omega from polynomial     YOE
# 0                              1.333236  2054.0
# 1                              1.398978  2037.0
# 2                              1.438698  2019.0
# 3                              1.437862  2020.0
# 4                              1.460498  2017.0
# ...

# %%
omega = pd.DataFrame(temp)
omega.dropna()
omega = omega.reset_index(drop = True)
omega.to_csv('/Users/akbaskind/Desktop/YoE/omegaYOE_091423.csv')

# %%
fig, axarr = plt.subplots(ncols = 3, figsize = [20,6])
axarr = axarr.flatten()
plt.rcParams.update({'font.size': 14})
plt.rc('xtick', labelsize=12)
plt.rc('ytick', labelsize=12)

# Select a location
ds = dd.sel(x = 180.5, y = 40.5, method = 'nearest')
tt = np.arange(1850,2100,1)

# PH
# Model
px = np.poly1d(np.polyfit(ds.t, ds.ph, 5))
sols_ph = px[0] + px[1] * tt + px[2] * tt**2 + px[3] * tt**3 + px[4] * tt**4 + px[5] * tt**5
ax = axarr[0]
ax.plot(tt,sols_ph, c = iris, label = '5th order polynomial model')
ax.scatter(ds.t, ds.ph, c = carrot,label = 'GFDL-ESM4')
# Noise
y = NOISE['Final Noise pH'].where(NOISE['Lat'] == 40.5).where(NOISE['Lon'] == 180.5).dropna().values.tolist()[0]
ax.fill_between(tt, sols_ph - y, sols_ph + y, color = iris, alpha = 0.2)
ax.fill_between(tt, sols_ph[0] - 2*y - y, sols_ph[0] - 2*y + y, color = jade, alpha = 0.2)
# YOE
yoe = ph['YOE'].where(ph['Lat'] == 40.5).where(ph['Lon'] == 180.5).dropna().tolist()[0]
ax.errorbar(yoe, sols_ph[0] - 2*y, yerr = y, marker = 'o', capsize = 3, color = jade)
ax.set_ylabel('pH')
ax.set_xlabel('Year')
ax.set_title('pH')

# FCO2
# Model
px = np.poly1d(np.polyfit(ds.t, ds.fCO2, 5))
sols_fco2 = px[0] + px[1] * tt + px[2] * tt**2 + px[3] * tt**3 + px[4] * tt**4 + px[5] * tt**5
ax = axarr[1]
ax.plot(tt,sols_fco2, c = iris, label = '5th order polynomial model')
ax.scatter(ds.t, ds.fCO2, c = carrot, label = 'GFDL-ESM4')
# Noise
y = NOISE['Final Noise fCO2'].where(NOISE['Lat'] == 40.5).where(NOISE['Lon'] == 180.5).dropna().values.tolist()[0]
ax.fill_between(tt, sols_fco2 - y, sols_fco2 + y, color = iris, alpha = 0.2)
ax.fill_between(tt, sols_fco2[0] + 2*y - y, sols_fco2[0] + 2*y + y, color = jade, alpha = 0.2)
# YOE
yoe = fco2['YOE'].where(fco2['Lat'] == 40.5).where(fco2['Lon'] == 180.5).dropna().tolist()[0]
ax.errorbar(yoe, sols_fco2[0] + 2*y, yerr = y, marker = 'o', capsize = 3, color = jade)
ax.set_ylabel('fCO$_2$')
ax.set_xlabel('Year')
ax.set_title('fCO$_2$')

# OMEGA
# Model
px = np.poly1d(np.polyfit(ds.t, ds.OmegaAr, 5))
sols = px[0] + px[1] * tt + px[2] * tt**2 + px[3] * tt**3 + px[4] * tt**4 + px[5] * tt**5  #+ px[6] * tt**6
ax = axarr[2]
ax.plot(tt,sols, c = iris, label = '5th order polynomial model')
ax.scatter(ds.t, ds.OmegaAr, c = carrot, label = 'GFDL-ESM4')
# Noise
y = NOISE['Final Noise Omega'].where(NOISE['Lat'] == 40.5).where(NOISE['Lon'] == 180.5).dropna().values.tolist()[0]
ax.fill_between(tt, sols - y, sols + y, color = iris, alpha = 0.2)
# YOE
yoe = omega['YOE'].where(omega['Lat'] == 40.5).where(omega['Lon'] == 180.5).dropna().tolist()[0]
ax.errorbar(yoe, sols[0] - 2*y, yerr = y, marker = 'o', capsize = 3, color = jade, label = 'Year of Emergence')
ax.set_ylabel('Ω$_{arag}$')
ax.fill_between(tt, sols[0] - 2*y - y, sols[0] - 2*y + y, color = jade, alpha = 0.2)
ax.set_xlabel('Year')
ax.set_title('Ω$_{arag}$')
ax.legend(bbox_to_anchor=(2, 0.5))

fig.suptitle('40.5°N, 180.5°')
fig.savefig('/Users/akbaskind/Documents/Python Scripts/YoE/40_5_180_5.png', bbox_inches='tight')

# %%
fco2 = pd.DataFrame(temp)
fco2.dropna()
# Out:
#         Lat    Lon   1850 fCO2  YOE Projected fCO2  \
# 6     -64.5    0.5  288.244764          338.241304
# 7     -63.5    0.5  285.572746          330.767572
# 8     -62.5    0.5  285.766766          325.944099
# 9     -61.5    0.5  288.083677          326.232820
# 10    -60.5    0.5  288.393817          327.414942
# ...     ...    ...         ...                 ...
# 44555  81.5  359.5  207.021215          285.273249
# 44556  82.5  359.5  218.552768          294.374399
# 44561  87.5  359.5  210.633289          275.489952
# 44562  88.5  359.5  209.904113          271.786205
# 44563  89.5  359.5  207.505549          269.299409
#
#        YOE Actual fCO2 from polynomial     YOE
# 6                           338.619958  1986.0
# 7                           331.341920  1977.0
# 8                           326.413926  1972.0
# 9                           326.281032  1972.0
# 10                          327.576136  1969.0
# ...                                ...     ...
# ...

# %%
ph = pd.read_csv('/Users/akbaskind/Desktop/YoE/phYOE_091423.csv')

# %%
2023 - ph['YOE'].max()
# Out:
# -36.0

# %%
fig, ax = plt.subplots(figsize = [20,20],subplot_kw={'projection':ccrs.PlateCarree()})
import cartopy as cart
plt.rcParams.update({'font.size': 18})
plt.rc('xtick', labelsize=18)
plt.rc('ytick', labelsize=18)

# Plot of mean detrended pH
x,y = np.meshgrid(ph['Lon'], ph['Lat'])
yoe = ax.scatter(ph['Lon'], ph['Lat'], c= ph['YOE'], vmin = 1850, vmax = 2100)
cbar0 = plt.colorbar(yoe, ax = ax, orientation = 'horizontal', fraction = 0.05, pad = 0.07)
cbar0.set_label('Year of Emergence')
ax.set_title('pH', fontsize = 24)
ax.set_xticks(np.arange(-180,181,60), crs=ccrs.PlateCarree())
lon_formatter = cticker.LongitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)
ax.set_yticks(np.arange(-90,91,30), crs=ccrs.PlateCarree())
lat_formatter = cticker.LatitudeFormatter()
ax.yaxis.set_major_formatter(lat_formatter)
# ax.coastlines()
ax.add_feature(cart.feature.LAND, facecolor='black')

fig.savefig('/Users/akbaskind/Documents/Python Scripts/YoE/pH_YOE.png', bbox_inches='tight')

# %%
fco2 = pd.read_csv('/Users/akbaskind/Desktop/YoE/fco2YOE_091423.csv')
fig, ax = plt.subplots(figsize = [20,20],subplot_kw={'projection':ccrs.PlateCarree()})
plt.rcParams.update({'font.size': 18})
plt.rc('ytick', labelsize=18)
plt.rc('xtick', labelsize=18)

# Plot of mean detrended pH
x,y = np.meshgrid(fco2['Lon'], fco2['Lat'])
yoe = ax.scatter(fco2['Lon'], fco2['Lat'], c= fco2['YOE'], vmin = 1850, vmax = 2100)
cbar0 = plt.colorbar(yoe, ax = ax, orientation = 'horizontal', fraction = 0.05, pad = 0.07)
cbar0.set_label('Year of Emergence')
ax.set_title('fCO$_2$', fontsize = 22)
ax.set_xticks(np.arange(-180,181,60), crs=ccrs.PlateCarree())
lon_formatter = cticker.LongitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)
ax.set_yticks(np.arange(-90,91,30), crs=ccrs.PlateCarree())
lat_formatter = cticker.LatitudeFormatter()
ax.yaxis.set_major_formatter(lat_formatter)
ax.add_feature(cart.feature.LAND, facecolor='black')

fig.savefig('/Users/akbaskind/Documents/Python Scripts/YoE/fCO2_YOE.png', bbox_inches='tight')

# %%
fco2 = pd.read_csv('/Users/akbaskind/Desktop/YoE/omegaYOE_091423.csv')
fig, ax = plt.subplots(figsize = [20,20],subplot_kw={'projection':ccrs.PlateCarree()})
plt.rcParams.update({'font.size': 18})
plt.rc('ytick', labelsize=18)
plt.rc('xtick', labelsize=18)

# Plot of mean detrended pH
x,y = np.meshgrid(fco2['Lon'], fco2['Lat'])
yoe = ax.scatter(fco2['Lon'], fco2['Lat'], c= fco2['YOE'], vmin = 1850, vmax = 2100)
cbar0 = plt.colorbar(yoe, ax = ax, orientation = 'horizontal', fraction = 0.05, pad = 0.07)
cbar0.set_label('Year of Emergence')
ax.set_title('Ω$_{arag}$', fontsize = 22)
ax.set_xticks(np.arange(-180,181,60), crs=ccrs.PlateCarree())
lon_formatter = cticker.LongitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)
ax.set_yticks(np.arange(-90,91,30), crs=ccrs.PlateCarree())
lat_formatter = cticker.LatitudeFormatter()
ax.yaxis.set_major_formatter(lat_formatter)
ax.add_feature(cart.feature.LAND, facecolor='black')

fig.savefig('/Users/akbaskind/Documents/Python Scripts/YoE/omega_YOE.png', bbox_inches='tight')

# %%
omega = pd.read_csv('/Users/akbaskind/Desktop/YoE/omegaYOE_091423.csv')
# for i in omega.index:
#     if math.isnan(omega['YOE'][i]):
#         print(i)
omega.iloc[9680]
# Out:
# Unnamed: 0                          9680.000000
# Lat                                   17.500000
# Lon                                   96.500000
# 1850 Omega                             0.910140
# YOE Projected Omega                   -0.124128
# YOE Actual Omega from polynomial            NaN
# YOE                                         NaN
# Name: 9680, dtype: float64

# %%
fig, axarr = plt.subplots(ncols = 3, figsize = [20,6])
axarr = axarr.flatten()
plt.rcParams.update({'font.size': 14})
plt.rc('xtick', labelsize=12)
plt.rc('ytick', labelsize=12)

# Select a location
lat = 54.5
lon = 9.5
ds = dd.sel(x = lon, y = lat, method = 'nearest')
tt = np.arange(1850,2100,1)

# PH
# Model
px = np.poly1d(np.polyfit(ds.t, ds.ph, 5))
sols_ph = px[0] + px[1] * tt + px[2] * tt**2 + px[3] * tt**3 + px[4] * tt**4 + px[5] * tt**5
ax = axarr[0]
ax.plot(tt,sols_ph, c = iris, label = '5th order polynomial model')
ax.scatter(ds.t, ds.ph, c = carrot,label = 'GFDL-ESM4')
# Noise
y = NOISE['Final Noise pH'].where(NOISE['Lat'] == lat).where(NOISE['Lon'] == lon).dropna().values.tolist()[0]
ax.fill_between(tt, sols_ph - y, sols_ph + y, color = iris, alpha = 0.2)
ax.fill_between(tt, sols_ph[0] - 2*y - y, sols_ph[0] - 2*y + y, color = jade, alpha = 0.2)
# YOE
# yoe = ph['YOE'].where(ph['Lat'] == lat).where(ph['Lon'] == lon).dropna().tolist()[0]
# ax.errorbar(yoe, sols_ph[0] - 2*y, yerr = y, marker = 'o', capsize = 3, color = jade)
ax.set_ylabel('pH')
ax.set_xlabel('Year')
ax.set_title('pH')

# FCO2
# Model
px = np.poly1d(np.polyfit(ds.t, ds.fCO2, 5))
sols_fco2 = px[0] + px[1] * tt + px[2] * tt**2 + px[3] * tt**3 + px[4] * tt**4 + px[5] * tt**5
ax = axarr[1]
ax.plot(tt,sols_fco2, c = iris, label = '5th order polynomial model')
ax.scatter(ds.t, ds.fCO2, c = carrot, label = 'GFDL-ESM4')
# Noise
y = NOISE['Final Noise fCO2'].where(NOISE['Lat'] == lat).where(NOISE['Lon'] == lon).dropna().values.tolist()[0]
ax.fill_between(tt, sols_fco2 - y, sols_fco2 + y, color = iris, alpha = 0.2)
ax.fill_between(tt, sols_fco2[0] + 2*y - y, sols_fco2[0] + 2*y + y, color = jade, alpha = 0.2)
# YOE
# yoe = fco2['YOE'].where(fco2['Lat'] == lat).where(fco2['Lon'] == lon).dropna().tolist()[0]
# ax.errorbar(yoe, sols_fco2[0] + 2*y, yerr = y, marker = 'o', capsize = 3, color = jade)
ax.set_ylabel('fCO$_2$')
ax.set_xlabel('Year')
ax.set_title('fCO$_2$')

# OMEGA
# Model
px = np.poly1d(np.polyfit(ds.t, ds.OmegaAr, 5))
sols = px[0] + px[1] * tt + px[2] * tt**2 + px[3] * tt**3 + px[4] * tt**4 + px[5] * tt**5  #+ px[6] * tt**6
ax = axarr[2]
ax.plot(tt,sols, c = iris, label = '5th order polynomial model')
ax.scatter(ds.t, ds.OmegaAr, c = carrot, label = 'GFDL-ESM4')
# Noise
y = NOISE['Final Noise Omega'].where(NOISE['Lat'] == lat).where(NOISE['Lon'] == lon).dropna().values.tolist()[0]
ax.fill_between(tt, sols - y, sols + y, color = iris, alpha = 0.2)
# YOE
# yoe = omega['YOE'].where(omega['Lat'] == lat).where(omega['Lon'] == lon).dropna().tolist()[0]
ax.errorbar(2000, sols[0] - 2*y, yerr = y, marker = 'o', capsize = 3, color = jade, label = 'Year of Emergence')
ax.set_ylabel('Ω$_{arag}$')
ax.fill_between(tt, sols[0] - 2*y - y, sols[0] - 2*y + y, color = jade, alpha = 0.2)
ax.set_xlabel('Year')
ax.set_title('Ω$_{arag}$')
ax.legend(bbox_to_anchor=(2, 0.5))

# fig.suptitle()
# fig.savefig('/Users/akbaskind/Documents/Python Scripts/YoE/40_5_180_5.png', bbox_inches='tight')

# %%
fig, axarr = plt.subplots(ncols = 3, figsize = [20,6])
axarr = axarr.flatten()
plt.rcParams.update({'font.size': 14})
plt.rc('xtick', labelsize=12)
plt.rc('ytick', labelsize=12)

# Select a location
lat = 17.5
lon = 96.5
ds = dd.sel(x = lon, y = lat, method = 'nearest')
tt = np.arange(1850,2100,1)

# PH
# Model
px = np.poly1d(np.polyfit(ds.t, ds.ph, 5))
sols_ph = px[0] + px[1] * tt + px[2] * tt**2 + px[3] * tt**3 + px[4] * tt**4 + px[5] * tt**5
ax = axarr[0]
ax.plot(tt,sols_ph, c = iris, label = '5th order polynomial model')
ax.scatter(ds.t, ds.ph, c = carrot,label = 'GFDL-ESM4')
# Noise
y = NOISE['Final Noise pH'].where(NOISE['Lat'] == lat).where(NOISE['Lon'] == lon).dropna().values.tolist()[0]
ax.fill_between(tt, sols_ph - y, sols_ph + y, color = iris, alpha = 0.2)
ax.fill_between(tt, sols_ph[0] - 2*y - y, sols_ph[0] - 2*y + y, color = jade, alpha = 0.2)
# YOE
# yoe = ph['YOE'].where(ph['Lat'] == lat).where(ph['Lon'] == lon).dropna().tolist()[0]
# ax.errorbar(yoe, sols_ph[0] - 2*y, yerr = y, marker = 'o', capsize = 3, color = jade)
ax.set_ylabel('pH')
ax.set_xlabel('Year')
ax.set_title('pH')

# FCO2
# Model
px = np.poly1d(np.polyfit(ds.t, ds.fCO2, 5))
sols_fco2 = px[0] + px[1] * tt + px[2] * tt**2 + px[3] * tt**3 + px[4] * tt**4 + px[5] * tt**5
ax = axarr[1]
ax.plot(tt,sols_fco2, c = iris, label = '5th order polynomial model')
ax.scatter(ds.t, ds.fCO2, c = carrot, label = 'GFDL-ESM4')
# Noise
y = NOISE['Final Noise fCO2'].where(NOISE['Lat'] == lat).where(NOISE['Lon'] == lon).dropna().values.tolist()[0]
ax.fill_between(tt, sols_fco2 - y, sols_fco2 + y, color = iris, alpha = 0.2)
ax.fill_between(tt, sols_fco2[0] + 2*y - y, sols_fco2[0] + 2*y + y, color = jade, alpha = 0.2)
# YOE
# yoe = fco2['YOE'].where(fco2['Lat'] == lat).where(fco2['Lon'] == lon).dropna().tolist()[0]
# ax.errorbar(yoe, sols_fco2[0] + 2*y, yerr = y, marker = 'o', capsize = 3, color = jade)
ax.set_ylabel('fCO$_2$')
ax.set_xlabel('Year')
ax.set_title('fCO$_2$')

# OMEGA
# Model
px = np.poly1d(np.polyfit(ds.t, ds.OmegaAr, 5))
sols = px[0] + px[1] * tt + px[2] * tt**2 + px[3] * tt**3 + px[4] * tt**4 + px[5] * tt**5  #+ px[6] * tt**6
ax = axarr[2]
ax.plot(tt,sols, c = iris, label = '5th order polynomial model')
ax.scatter(ds.t, ds.OmegaAr, c = carrot, label = 'GFDL-ESM4')
# Noise
y = NOISE['Final Noise Omega'].where(NOISE['Lat'] == lat).where(NOISE['Lon'] == lon).dropna().values.tolist()[0]
ax.fill_between(tt, sols - y, sols + y, color = iris, alpha = 0.2)
# YOE
# yoe = omega['YOE'].where(omega['Lat'] == lat).where(omega['Lon'] == lon).dropna().tolist()[0]
# ax.errorbar(yoe, sols[0] - 2*y, yerr = y, marker = 'o', capsize = 3, color = jade, label = 'Year of Emergence')
ax.set_ylabel('Ω$_{arag}$')
ax.fill_between(tt, sols[0] - 2*y - y, sols[0] - 2*y + y, color = jade, alpha = 0.2)
ax.set_xlabel('Year')
ax.set_title('Ω$_{arag}$')
ax.legend(bbox_to_anchor=(2, 0.5))

fig.suptitle('17.5°N, 96.5°W')
fig.savefig('/Users/akbaskind/Documents/Python Scripts/YoE/17_5_96_5.png', bbox_inches='tight')

# %% [markdown]
# # Conceptual background for 5th order polynomial

# %%
#fit polynomial models up to degree 5
model1 = np.poly1d(np.polyfit(ds.t, ds.ph, 1))
model2 = np.poly1d(np.polyfit(ds.t, ds.ph, 2))
model3 = np.poly1d(np.polyfit(ds.t, ds.ph, 6))
model4 = np.poly1d(np.polyfit(ds.t, ds.ph, 4))
model5 = np.poly1d(np.polyfit(ds.t, ds.ph, 5))

#create scatterplot
polyline = np.linspace(1850, 2050, 10)
plt.scatter(ds.t, ds.ph)

#add fitted polynomial lines to scatterplot 
# plt.plot(polyline, model1(polyline), color='green')
# plt.plot(polyline, model2(polyline), color='red')
# plt.plot(polyline, model3(polyline), color='purple')
plt.plot(polyline, model4(polyline), color='blue')
plt.plot(polyline, model5(polyline), color='orange')
plt.show()

# %%
sols = px[0] + px[1] * tt + px[2] * tt**2 + px[3] * tt**3 + px[4] * tt**4 + px[5] * tt**5
# sols.tolist()

projph = ds.ph.isel(t = 0) - 2*noise
projph.values.tolist()
# Out:
# 8.09155029296875

# %% [markdown]
# $$-6.24923762\times 10^{-12} + 5.91599898 \times 10^{-8} t -2.23971622 \times 10^{-4} t^2 + 4.23867155 \times 10^{-1} t^3 -4.00992934 \times 10^{2} t^4 + 1.51714079 \times 10^{5} t^5$$

# %%
ds = dd_.isel(y=0,x=0)
ds.ph.values
# Out:
# array([8.15155029, 8.15369701, 8.14995289, 8.15047359, 8.14445591,
#        8.1413126 , 8.13619041, 8.13044071, 8.12630177, 8.12390518,
#        8.12132835, 8.12170506, 8.11163425, 8.09913158, 8.08558464,
#        8.08857059, 8.08578968, 8.0854454 , 8.08116436, 8.07936096,
#        8.0760479 , 8.07128429, 8.07687092, 8.07105827, 8.07072258,
#        8.06880093, 8.06893539, 8.06246471, 8.0600214 , 8.06254387,
#        8.06320477, 8.0586338 , 8.05455303, 8.05037403, 8.05285549,
#        8.05393314, 8.04901981, 8.04548645, 8.04492569, 8.03757763,
#        8.03360367, 8.03115273, 8.03793144, 8.03356838, 8.03089428,
#        8.03149509, 8.02083683, 8.02067852, 8.02049446, 8.01819324,
#        8.01182842, 8.01317501, 8.00870323, 8.01059818, 8.00690365])

# %%
px = np.poly1d(np.polyfit(ds.t, ds.ph, 5))
t = np.arange(1850,2060,1)
fpx = px[0] + px[1] * t + px[2] * t**2 + px[3] * t**3 + px[4] * t**4 + px[5] * t**5 + px[6] * t**6 
plt.scatter(ds.t, ds.ph)
plt.plot(t, px(t))
# plt.plot(polyline, px(t) + noise)
# plt.plot(polyline, px(t) - noise)
# plt.plot(t, quintic_polynomial(px, t))

# plt.scatter(1983, 8.15527126312256 - noise)
